# %% [markdown]
# # Fase 5 — Exportação (.xlsx consolidado)
#
# Consolida todos os CSVs Gold em um único arquivo `.xlsx` com abas separadas por dimensão.
#
# **Pré-requisito:** `03_gold.ipynb` já executado (gold populado).

# %%
import sys, pathlib

_root = pathlib.Path.cwd()
if not (_root / "config.py").exists():
    _root = _root.parent
if str(_root) not in sys.path:
    sys.path.insert(0, str(_root))

# %%
from config import config

print(f"Gold dir : {config.gold_dir}")
# Out:
# Gold dir : c:\Users\yaelh\Documents\GitHub\Trabalho_Integrador_6\dados\gold

# %%
from analise.consolidar_gold import consolidar

print("=== Fase 5 — Exportando Gold ===")
consolidar(config.gold_dir)
print("\nPipeline concluído!")
# Out:
# === Fase 5 — Exportando Gold ===
#   [gold] aba 'Gap Salarial UF' → 48 linhas
#   [gold] aba 'Gap Escolaridade' → 120 linhas
#   [gold] aba 'Gap Setor' → 630 linhas
#   [gold] aba 'Ocupacao' → 65,066 linhas
#   [gold] aba 'Vagas Saldo' → 2,898 linhas
#
#   [gold] consolidado → c:\Users\yaelh\Documents\GitHub\Trabalho_Integrador_6\dados\gold\mercado_trabalho_consolidado.xlsx
#
# Pipeline concluído!
