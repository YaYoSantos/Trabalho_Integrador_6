# %% [markdown]
# # Fase 3 — Normalização (Silver)
#
# Lê os arquivos brutos do Bronze, normaliza tipos e salva CSVs padronizados em `silver/`.
#
# **Pré-requisito:** `01_coleta.ipynb` já executado (bronze populado).

# %%
import sys, pathlib

_root = pathlib.Path.cwd()
if not (_root / "config.py").exists():
    _root = _root.parent
if str(_root) not in sys.path:
    sys.path.insert(0, str(_root))

# %%
from config import config

print(f"Bronze dir : {config.bronze_dir}")
print(f"Silver dir : {config.silver_dir}")
# Out:
# Bronze dir : c:\Users\yaelh\Documents\GitHub\Trabalho_Integrador_6\dados\bronze
# Silver dir : c:\Users\yaelh\Documents\GitHub\Trabalho_Integrador_6\dados\silver

# %%
from silver import PnadNormalizer

print("=== Fase 3.1 — Normalizar PNAD ===")
pnad_norm = PnadNormalizer(config.bronze_dir, config.silver_dir)
df_pnad = pnad_norm.normalize()
df_pnad.head()
# Out:
# === Fase 3.1 — Normalizar PNAD ===
#   [pnad silver] 5,920 linhas → c:\Users\yaelh\Documents\GitHub\Trabalho_Integrador_6\dados\silver\pnad_limpo.csv
#   tabela_id uf_cod uf_nome periodo sexo_cod       sexo   valor regiao_cod  \
# 0      4093     41  Paraná  202001        4  Masculino  4529.0        NaN
# 1      4093     41  Paraná  202001        5   Feminino  4701.0        NaN
# 2      4093     41  Paraná  202001        4  Masculino     0.7        NaN
# 3      4093     41  Paraná  202001        5   Feminino     0.7        NaN
# 4      4093     41  Paraná  202001        4  Masculino    49.1        NaN
#
#   regiao_nome
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
from silver import CagedNormalizer

print("=== Fase 3.2 — Normalizar CAGED ===")
caged_norm = CagedNormalizer(config.bronze_dir, config.silver_dir)
df_caged = caged_norm.normalize()
df_caged.head()
# Out:
# === Fase 3.2 — Normalizar CAGED ===
#   [caged silver] 50,373,535 linhas → c:\Users\yaelh\Documents\GitHub\Trabalho_Integrador_6\dados\silver\caged_limpo.csv
#     ano  mes sigla_uf       sexo  grau_instrucao cbo_2002 cnae_2_subclasse  \
# 0  2020    4       SC  Masculino               7   782510          4744099
# 1  2020    4       SC  Masculino               7   623015          0154700
# 2  2020    4       SC   Feminino               6   513205          0210108
# 3  2020    4       SC  Masculino               7   782510          0810009
# 4  2020    4       SC   Feminino               1   848520          1012101
#
#    tipo_movimentacao  saldo_movimentacao  salario_mensal faixa_etaria
# 0                 20                   1         1800.00        40-49
# 1                 40                  -1         1630.24        18-24
# 2                 20                   1         1045.00        30-39
# 3                 20                   1         1847.96        25-29
# 4                 40                  -1         1377.89        18-24

# %%
from silver import RaisNormalizer

print("=== Fase 3.3 — Normalizar RAIS ===")
rais_norm = RaisNormalizer(config.bronze_dir, config.silver_dir)
df_rais = rais_norm.normalize()
df_rais.head()
# Out:
# === Fase 3.3 — Normalizar RAIS ===
#   [rais silver] 45,717,633 linhas → c:\Users\yaelh\Documents\GitHub\Trabalho_Integrador_6\dados\silver\rais_limpo.csv
#     ano sigla_uf       sexo  idade cbo_2002 cnae_2_subclasse  \
# 0  2020       PR  Masculino     21   612505          0131800
# 1  2020       PR  Masculino     20   612505          0131800
# 2  2020       PR   Feminino     32   763215          1412601
# 3  2020       PR   Feminino     43   763210          1412603
# 4  2020       PR  Masculino     21   784205          1610203
#
#    valor_remuneracao_media  grau_instrucao_apos_2005 faixa_etaria_calculada
# 0                  1678.39                         6                  18-24
# 1                  1303.84                         6                  18-24
# 2                  1423.20                         7                  30-39
# 3                   654.15                         7                  40-49
# 4                   412.36                         6                  18-24
